# %%
import sys
sys.path.append('C:/Users/DVOS/Documents/Github/cmglib/cmglib')

# %%
import pandas as pd
import numpy as np
from report import Report
from pathlib import Path

# %%
sr3_folder = '../cmglib/'
tpl = 'TemplateReport.tpl'
report = Report(tpl)
prices = np.array([283, 0, -38, -13])
tma = 0.08

files = []
npv = []

for sr3_file in Path(sr3_folder).rglob('*.sr3'):
    print(sr3_file.stem)
    files += [sr3_file.stem]
    code = report.run_report(sr3_file)
    report.read_rwo()
    npv_real = report.npv(tma, prices)
    print(f'O valor de npv é {npv_real}')
    npv.append(npv_real)
    # repor
# Out:
# WARNING:root:O arquivo OLYMPUS_BHP_noWC_1 já existe e não será sobrescrito.
# WARNING:root:O arquivo OLYMPUS_BHP_noWC_30 já existe e não será sobrescrito.
# WARNING:root:O arquivo OLYMPUS_BHP_RC_10 já existe e não será sobrescrito.
# OLYMPUS_BHP_noWC_1
# O valor de npv é 1117176396.174203
# OLYMPUS_BHP_noWC_30
# O valor de npv é 1531510115.232533
# OLYMPUS_BHP_RC_10
# O valor de npv é 1933347055.9745142

# %%
sr3_folder = '../cmglib/'
tpl = 'TemplateReport.tpl'
report = Report(tpl)
prices = np.array([283, 0, -38, -13])
tma = 0.08

files = []
npv = []

for sr3_file in Path(sr3_folder).rglob('*.sr3'):
    print(sr3_file.stem)
    files += [sr3_file.stem]
    code = report.run_report(sr3_file)
    report.read_rwo()
    npv_real = report.npv(tma, prices)
    print(f'O valor de npv é {npv_real}')
    npv.append(npv_real)
    # repor
# Out:
# WARNING:root:O arquivo OLYMPUS_BHP_noWC_1 já existe e não será sobrescrito.
# WARNING:root:O arquivo OLYMPUS_BHP_noWC_30 já existe e não será sobrescrito.
# WARNING:root:O arquivo OLYMPUS_BHP_RC_10 já existe e não será sobrescrito.
# OLYMPUS_BHP_noWC_1
# O valor de npv é 1106932526.9583206
# OLYMPUS_BHP_noWC_30
# O valor de npv é 1518120627.5355854
# OLYMPUS_BHP_RC_10
# O valor de npv é 1935391272.3413777

# %%
report.rwo
# Out:
#      time  oil_prod  gas_prod   water_prod  water_inj     cash_flow
# 0       0       0.0         0      0.00000        0.0  0.000000e+00
# 1      31  165347.0         0      7.91317    89272.3  4.563236e+07
# 2      60  116179.0         0      6.28462   104663.0  3.151780e+07
# 3      91  125039.0         0     14.32910   124035.0  3.377304e+07
# 4     121  122798.0         0     56.09420   126933.0  3.309957e+07
# ..    ...       ...       ...          ...        ...           ...
# 236  7183   22033.3         0  95822.10000   119433.0  1.041555e+06
# 237  7213   21208.8         0  92988.10000   115714.0  9.642606e+05
# 238  7244   21797.6         0  96354.70000   119711.0  9.509992e+05
# 239  7274   20984.0         0  93498.40000   115981.0  8.777798e+05
# 240  7305   21568.9         0  96876.80000   119986.0  8.628623e+05
#
# [241 rows x 6 columns]

# %%
sr3_folder = r'C:\Users\DVOS\OneDrive - PETROBRAS\Documentos\Pessoais\Doutorado\Softwares\ReservoirsDATA\OLYMPUS\OLYMPUS\Results_HF\ALL_OPEN_BHP_noWC'
tpl = 'TemplateReport.tpl'
report = Report(tpl)
prices = np.array([283, 0, -38, -13])
tma = 0.08

files = []
npv = []

for sr3_file in Path(sr3_folder).rglob('*.sr3'):
    print(sr3_file.stem)
    files += [sr3_file.stem]
    code = report.run_report(sr3_file)
    report.read_rwo()
    npv_real = report.npv(tma, prices)
    print(f'O valor de npv é {npv_real}')
    npv.append(npv_real)
    # repor
# Out:
# OLYMPUS_BHP_noWC_1
# O valor de npv é 1106932526.9583206
# OLYMPUS_BHP_noWC_10
# O valor de npv é 1604025969.8875341
# OLYMPUS_BHP_noWC_11
# O valor de npv é 1354873268.8719497
# OLYMPUS_BHP_noWC_12
# O valor de npv é 1399081760.5336957
# OLYMPUS_BHP_noWC_13
# O valor de npv é 1283325483.7455654
# OLYMPUS_BHP_noWC_14
# O valor de npv é 1381745661.884665
# OLYMPUS_BHP_noWC_15
# O valor de npv é 957473559.2600914
# OLYMPUS_BHP_noWC_16
# O valor de npv é 1247788343.7123067
# OLYMPUS_BHP_noWC_17
# O valor de npv é 1259763680.298112
# OLYMPUS_BHP_noWC_18
# O valor de npv é 1096717636.9757924
# OLYMPUS_BHP_noWC_19
# O valor de npv é 1445924137.5133994
# OLYMPUS_BHP_noWC_2
# O valor de npv é 1461817955.9637625
# OLYMPUS_BHP_noWC_20
# O valor de npv é 1699623956.7339447
# OLYMPUS_BHP_noWC_21
# O valor de npv é 1525600009.6384454
# OLYMPUS_BHP_noWC_22
# O valor de npv é 974417472.5289322
# OLYMPUS_BHP_noWC_23
# O valor de npv é 1451130981.5451705
# OLYMPUS_BHP_noWC_24
# O valor de npv é 1050672612.1993746
# OLYMPUS_BHP_noWC_25
# O valor de npv é 1291050784.3952637
# OLYMPUS_BHP_noWC_26
# O valor de npv é 992928338.3935143
# OLYMPUS_BHP_noWC_27
# O valor de npv é 1383226895.098096
# OLYMPUS_BHP_noWC_28
# O valor de npv é 1096917637.4929817
# OLYMPUS_BHP_noWC_29
# O valor de npv é 1435052987.7827644
# OLYMPUS_BHP_noWC_3
# O valor de npv é 1531783967.4432802
# OLYMPUS_BHP_noWC_30
# O valor de npv é 1518120627.5355854
# OLYMPUS_BHP_noWC_31
# O valor de npv é 1113521713.060624
# OLYMPUS_BHP_noWC_32
# O valor de npv é 1326940879.1698914
# OLYMPUS_BHP_noWC_33
# O valor de npv é 1288118556.24242
# OLYMPUS_BHP_noWC_34
# O valor de npv é 1368100152.2425938
# OLYMPUS_BHP_noWC_35
# O valor de npv é 1656690014.5122378
# OLYMPUS_BHP_noWC_36
# O valor de npv é 1312415588.8547366
# OLYMPUS_BHP_noWC_37
# O valor de npv é 1273769250.2930703
# OLYMPUS_BHP_noWC_38
# O valor de npv é 1379066042.2545235
# OLYMPUS_BHP_noWC_39
# O valor de npv é 1000948372.5955089
# OLYMPUS_BHP_noWC_4
# O valor de npv é 1036176173.124637
# OLYMPUS_BHP_noWC_40
# O valor de npv é 924681055.8042418
# OLYMPUS_BHP_noWC_41
# O valor de npv é 1266360564.5070734
# OLYMPUS_BHP_noWC_42
# O valor de npv é 1427575929.0222962
# OLYMPUS_BHP_noWC_43
# O valor de npv é 1341748305.9433587
# OLYMPUS_BHP_noWC_44
# O valor de npv é 1331184534.6238363
# OLYMPUS_BHP_noWC_45
# O valor de npv é 1304980459.0187721
# OLYMPUS_BHP_noWC_46
# O valor de npv é 1258908833.4436436
# OLYMPUS_BHP_noWC_47
# O valor de npv é 1518121562.015115
# OLYMPUS_BHP_noWC_48
# O valor de npv é 1214026365.3171635
# OLYMPUS_BHP_noWC_49
# O valor de npv é 1577335815.5657167
# OLYMPUS_BHP_noWC_5
# O valor de npv é 1173962457.9199698
# OLYMPUS_BHP_noWC_50
# O valor de npv é 1088073396.2597828
# OLYMPUS_BHP_noWC_6
# O valor de npv é 1038438547.6046335
# OLYMPUS_BHP_noWC_7
# O valor de npv é 1182319676.0867743
# OLYMPUS_BHP_noWC_8
# O valor de npv é 1288783481.9296637
# OLYMPUS_BHP_noWC_9
# O valor de npv é 1316192909.3924415

# %%
report.rwo
# Out:
#      time  oil_prod  gas_prod    water_prod  water_inj     cash_flow
# 0       0       0.0         0       0.00000        0.0  0.000000e+00
# 1      31  171872.0         0       9.35625    96593.3  4.738371e+07
# 2      60  130186.0         0       6.90583   113062.0  3.537257e+07
# 3      91  138981.0         0      26.68370   132962.0  3.760210e+07
# 4     121  134652.0         0      96.83960   135068.0  3.634695e+07
# ..    ...       ...       ...           ...        ...           ...
# 236  7183   23054.3         0  233430.00000   257854.0 -5.698075e+06
# 237  7213   22098.9         0  226146.00000   249604.0 -5.584411e+06
# 238  7244   22685.9         0  233974.00000   257995.0 -5.824837e+06
# 239  7274   21788.5         0  226656.00000   249739.0 -5.693390e+06
# 240  7305   22375.2         0  234431.00000   258134.0 -5.931938e+06
#
# [241 rows x 6 columns]

# %%
data = dict(zip(files, npv))
df = pd.Series(data=data, index=files)

# %%
df.to_csv(r'C:\Users\DVOS\OneDrive - PETROBRAS\Documentos\Pessoais\Doutorado\Softwares\ReservoirsDATA\OLYMPUS\OLYMPUS\Results_HF\ALL_OPEN_BHP_noWC\npv_results_noWC.csv')

# %%
df.describe()
# Out:
# count    5.000000e+01
# mean     1.291169e+09
# std      1.912057e+08
# min      9.246811e+08
# 25%      1.128632e+09
# 50%      1.298016e+09
# 75%      1.420452e+09
# max      1.699624e+09
# dtype: float64

# %%
npv[-1]
# Out:
# 1615170381.7060425

# %%
rc = pd.read_csv(r"C:\Users\DVOS\OneDrive - PETROBRAS\Documentos\Pessoais\Doutorado\Softwares\ReservoirsDATA\OLYMPUS\OLYMPUS\Results_HF\RC_BHP_with_WC\npv_results_RC.csv")

# %%
rc.describe()
# Out:
#                 npv
# count  5.000000e+01
# mean   1.489577e+09
# std    2.252611e+08
# min    9.859609e+08
# 25%    1.324884e+09
# 50%    1.515810e+09
# 75%    1.638816e+09
# max    1.935391e+09

# %%
rc.sort_values(by=['npv'])
# Out:
#                 files           npv
# 34  OLYMPUS_BHP_RC_40  9.859609e+08
# 18  OLYMPUS_BHP_RC_26  1.008381e+09
# 33   OLYMPUS_BHP_RC_4  1.119813e+09
# 20  OLYMPUS_BHP_RC_28  1.194734e+09
# 14  OLYMPUS_BHP_RC_22  1.198794e+09
# 44   OLYMPUS_BHP_RC_5  1.227521e+09
# 0    OLYMPUS_BHP_RC_1  1.255494e+09
# 47   OLYMPUS_BHP_RC_7  1.256569e+09
# 32  OLYMPUS_BHP_RC_39  1.277155e+09
# 42  OLYMPUS_BHP_RC_48  1.287612e+09
# 35  OLYMPUS_BHP_RC_41  1.302858e+09
# 24  OLYMPUS_BHP_RC_31  1.303658e+09
# 7   OLYMPUS_BHP_RC_16  1.316952e+09
# 6   OLYMPUS_BHP_RC_15  1.348680e+09
# 45  OLYMPUS_BHP_RC_50  1.349816e+09
# 9   OLYMPUS_BHP_RC_18  1.365250e+09
# 48   OLYMPUS_BHP_RC_8  1.368998e+09
# 39  OLYMPUS_BHP_RC_45  1.369365e+09
# 17  OLYMPUS_BHP_RC_25  1.402866e+09
# 19  OLYMPUS_BHP_RC_27  1.416941e+09
# 46   OLYMPUS_BHP_RC_6  1.428578e+09
# 16  OLYMPUS_BHP_RC_24  1.434976e+09
# 40  OLYMPUS_BHP_RC_46  1.468031e+09
# 30  OLYMPUS_BHP_RC_37  1.487280e+09
# 38  OLYMPUS_BHP_RC_44  1.507298e+09
# 25  OLYMPUS_BHP_RC_32  1.524323e+09
# 5   OLYMPUS_BHP_RC_14  1.529045e+09
# 29  OLYMPUS_BHP_RC_36  1.536044e+09
# 15  OLYMPUS_BHP_RC_23  1.541333e+09
# 2   OLYMPUS_BHP_RC_11  1.558118e+09
# 13  OLYMPUS_BHP_RC_21  1.566455e+09
# 36  OLYMPUS_BHP_RC_42  1.578186e+09
# 37  OLYMPUS_BHP_RC_43  1.602898e+09
# 10  OLYMPUS_BHP_RC_19  1.608306e+09
# 21  OLYMPUS_BHP_RC_29  1.611382e+09
# 49   OLYMPUS_BHP_RC_9  1.615170e+09
# 11   OLYMPUS_BHP_RC_2  1.623507e+09
# 31  OLYMPUS_BHP_RC_38  1.643919e+09
# 27  OLYMPUS_BHP_RC_34  1.644875e+09
# 3   OLYMPUS_BHP_RC_12  1.647111e+09
# 8   OLYMPUS_BHP_RC_17  1.658063e+09
# 4   OLYMPUS_BHP_RC_13  1.659842e+09
# 41  OLYMPUS_BHP_RC_47  1.689195e+09
# 26  OLYMPUS_BHP_RC_33  1.714837e+09
# 23  OLYMPUS_BHP_RC_30  1.764889e+09
# 28  OLYMPUS_BHP_RC_35  1.865247e+09
# 22   OLYMPUS_BHP_RC_3  1.875879e+09
# 43  OLYMPUS_BHP_RC_49  1.879641e+09
# 12  OLYMPUS_BHP_RC_20  1.921611e+09
# 1   OLYMPUS_BHP_RC_10  1.935391e+09

# %%
rc.quantile(.05)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 rc.quantile(.05)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10875 axis = self._get_axis_number(axis)
#   10877 if not is_list_like(q):
#   10878     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   10879     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   10880     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881     # expected "float"
# > 10882     res_df = self.quantile(  # type: ignore[call-overload]
#   10883         [q],
#   10884         axis=axis,
#   10885         numeric_only=numeric_only,
#   10886         interpolation=interpolation,
#   10887         method=method,
#   10888     )
#   10889     if method == "single":
#   10890         res = res_df.iloc[0]
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\frame.py:10927, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10923     raise ValueError(
#   10924         f"Invalid method: {method}. Method must be in {valid_method}."
#   10925     )
#   10926 if method == "single":
# > 10927     res = data._mgr.quantile(qs=q, axis=1, interpolation=interpolation)
#   10928 elif method == "table":
#   10929     valid_interpolation = {"nearest", "lower", "higher"}
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\internals\managers.py:1587, in BlockManager.quantile(self, qs, axis, interpolation)
#    1584 new_axes = list(self.axes)
#    1585 new_axes[1] = Index(qs, dtype=np.float64)
# -> 1587 blocks = [
#    1588     blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1589     for blk in self.blocks
#    1590 ]
#    1592 return type(self)(blocks, new_axes)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\internals\managers.py:1588, in <listcomp>(.0)
#    1584 new_axes = list(self.axes)
#    1585 new_axes[1] = Index(qs, dtype=np.float64)
#    1587 blocks = [
# -> 1588     blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1589     for blk in self.blocks
#    1590 ]
#    1592 return type(self)(blocks, new_axes)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1463, in Block.quantile(self, qs, interpolation, axis)
#    1460 assert axis == 1  # only ever called this way
#    1461 assert is_list_like(qs)  # caller is responsible for this
# -> 1463 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1464 # ensure_block_shape needed for cases where we start with EA and result
#    1465 #  is ndarray, e.g. IntegerArray, SparseArray
#    1466 result = ensure_block_shape(result, ndim=2)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\array_algos\quantile.py:37, in quantile_compat(values, qs, interpolation)
#      35     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      36     mask = isna(values)
# ---> 37     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      38 else:
#      39     return values._quantile(qs, interpolation)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\array_algos\quantile.py:95, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      93     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      94 else:
# ---> 95     result = _nanpercentile(
#      96         values,
#      97         qs * 100.0,
#      98         na_value=fill_value,
#      99         mask=mask,
#     100         interpolation=interpolation,
#     101     )
#     103     result = np.array(result, copy=False)
#     104     result = result.T
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\pandas\core\array_algos\quantile.py:216, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     214     return result
#     215 else:
# --> 216     return np.percentile(
#     217         values,
#     218         qs,
#     219         axis=1,
#     220         # error: No overload variant of "percentile" matches argument types
#     221         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     222         # "int", "Dict[str, str]"  [call-overload]
#     223         **{np_percentile_argname: interpolation},  # type: ignore[call-overload]
#     224     )
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\numpy\lib\function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\numpy\lib\function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\numpy\lib\function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\numpy\lib\function_base.py:4721, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4719     else:
#    4720         arr = a.copy()
# -> 4721 result = _quantile(arr,
#    4722                    quantiles=q,
#    4723                    axis=axis,
#    4724                    method=method,
#    4725                    out=out)
#    4726 return result
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\numpy\lib\function_base.py:4840, in _quantile(arr, quantiles, axis, method, out)
#    4838     result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4839     gamma = gamma.reshape(result_shape)
# -> 4840     result = _lerp(previous,
#    4841                    next,
#    4842                    gamma,
#    4843                    out=out)
#    4844 if np.any(slices_having_nans):
#    4845     if result.ndim == 0 and out is None:
#    4846         # can't write to a scalar, but indexing will be correct
#
# File c:\Users\DVOS\Documents\Github\cmglib\.venv\Lib\site-packages\numpy\lib\function_base.py:4655, in _lerp(a, b, t, out)
#    4641 def _lerp(a, b, t, out=None):
#    4642     """
#    4643     Compute the linear interpolation weighted by gamma on each point of
#    4644     two same shape array.
#    (...)
#    4653         Output array.
#    4654     """
# -> 4655     diff_b_a = subtract(b, a)
#    4656     # asanyarray is a stop-gap until gh-13105
#    4657     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
